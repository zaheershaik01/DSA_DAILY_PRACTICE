# %% [markdown]
# ### Lambda Functions in Python ###
# Lambda functions are small anonymous functions defined using the lambda keyword. They can have any number of arguments but only one expression. They are commonly used for short operations or as an arguments to higher-order functions.

# %%
#Syntax
lambda arguments: expression

# %%
def addition(a, b):
    return a+b

# %%
addition(3,4)
# Out:
# 7

# %%
addition=lambda a,b:a+b
type(addition)
print(addition(3,4))
# Out:
# 7

# %%
def even(num):
    if num%2==0:
        return True

even(56)
# Out:
# True

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x, y, z):
    return x+y+z

addition(3,4,5)
# Out:
# 12

# %%
addition1= lambda x,y,z:x+y+z
addition1(3,4,5)
# Out:
# 12

# %%
## map() - applies a function to all items in a list
numbers=[1,2,3,4,5,6]
def square(number):
    return number**2

square(2)
# Out:
# 4

# %%
list(map(lambda x:x**2, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]
